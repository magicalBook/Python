# %%
import torch.nn as nn

class ResBlock(nn.Module):
    def __init__(self, inChannel, outChannel, downSampling=False, upSampling=False):
        super().__init__()
        # (Lin + 2P -k) / S + 1
        self.down = nn.Conv1d(inChannel, outChannel, kernel_size=2, padding=0, stride=2)
        # (Lin-1) * S - 2P + k
        self.up = nn.ConvTranspose1d(inChannel, outChannel, kernel_size=2, stride=2, padding=0)
        self.relu = nn.ReLU(inplace=True)
        self.downSampling = downSampling
        self.upSampling = upSampling
        
        assert not downSampling or not upSampling, "Can't perform downsampling and upsampline simultaneously."
        layers = []

        if downSampling:
            layers.append(nn.Conv1d(inChannel, outChannel, kernel_size=3, padding=1))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(outChannel, outChannel, kernel_size=2, padding=0, stride=2))
            
        elif upSampling:
            layers.append(nn.ConvTranspose1d(inChannel, outChannel, kernel_size=2, stride=2, padding=0))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(outChannel, outChannel, kernel_size=3, padding=1))
            
        else:
            layers.append(nn.Conv1d(inChannel, outChannel, kernel_size=3, padding=1))
            layers.append(nn.ReLU(inplace=True))
            layers.append(nn.Conv1d(outChannel, outChannel, kernel_size=3, padding=1))

        self.block = nn.Sequential(*layers)
    
    def forward(self, inPut):
        residual = inPut
        out = self.block(inPut)
        if self.downSampling:
            residual = self.down(inPut)
        elif self.upSampling:
            residual = self.up(inPut)
            
        out += residual
        out = self.relu(out)
        
        return out      
        
        
class ResNet(nn.Module):
    def __init__(self, firstChannels=[32, 64, 128], secondChannels=[128, 64, 32], firstBlockRepeats=[1, 1, 1], secBlockRepeats=[1, 1, 1],
                 upsampling=[False, True, True], downsampling=[False, True, True], useUpsampling=False,
                 dataLen=512, outSizeChange=False, numClasses=1):
        super(ResNet, self).__init__()
        outSize = dataLen*(2**(-sum(downsampling)+sum(upsampling))) if useUpsampling else dataLen*(2**(-sum(downsampling)-sum(upsampling)))
        self.preLayer = nn.Conv1d(1, firstChannels[0], kernel_size=3, padding=1)
        self.relu = nn.ReLU(inplace=True)
        self.fc = nn.Flatten()
        
        self.linear1 = nn.Linear(int(outSize), numClasses) if outSizeChange else nn.Linear(int((secondChannels[-1])*outSize), numClasses)
        
        self.firstModule = nn.ModuleList([ResBlock(firstChannels[0], firstChannels[0], downSampling=downsampling[0])]*firstBlockRepeats[0])
        for i in range(1, len(firstChannels)):
            self.firstModule.append(ResBlock(firstChannels[i-1], firstChannels[i], downSampling=downsampling[i]))
            for j in range(firstBlockRepeats[i]):
                self.firstModule.append(ResBlock(firstChannels[i], firstChannels[i], downSampling=downsampling[0]))
            
        assert firstChannels[-1] == secondChannels[0], 'the last value of firstChannels should equal to the first value of secondChannels'
        
        #self.outLayers = nn.ModuleList([ResBlock(secondChannels[0]*2, secondChannels[0], True)]) #use torch.cat
        self.secondModule = nn.ModuleList([])
        if useUpsampling:
            for i in range(1, len(secondChannels)):
                self.secondModule.append(ResBlock(secondChannels[i-1], secondChannels[i], upSampling=upsampling[i]))
                for j in range(secBlockRepeats[i]):
                    self.secondModule.append(ResBlock(secondChannels[i], secondChannels[i], upSampling=upsampling[0]))
                    
        else:
            for i in range(1, len(secondChannels)):
                self.secondModule.append(ResBlock(secondChannels[i-1], secondChannels[i], downSampling=upsampling[i]))
                for j in range(secBlockRepeats[i]):
                    self.secondModule.append(ResBlock(secondChannels[i], secondChannels[i], upSampling=upsampling[0]))
            
        if len(secondChannels)==1:self.secondModule.append(ResBlock(secondChannels[0], secondChannels[0]))
            
        if outSizeChange: self.secondModule.append(nn.Conv1d(secondChannels[-1], 1, kernel_size=1, stride=1, padding=0)) 
        
    def forward(self, inPut1, inPut2):
        data1 = inPut1.view(-1, 1, 512)
        data2 = inPut2.view(-1, 1, 512)
        
        out1 = self.relu(self.preLayer(data1))
        out2 = self.relu(self.preLayer(data2))
        
        for layer in self.firstModule:
            out1 = layer(out1)
            out2 = layer(out2)
            
        out = torch.sub(out1, out2)
        #out = torch.cat((out1, out2), dim=1)
        for layer in self.secondModule:
            out = layer(out)
            
        out = self.fc(out)
        out = self.linear1(out)
        
        return out

# %%
import torch
device = torch.device('cpu')
myNet = ResNet(firstChannels=[32, 48, 72], secondChannels=[72, 48, 32], 
               firstBlockRepeats=[1, 1, 1], secBlockRepeats=[1, 1, 1], 
               downsampling=[False, True, True], upsampling=[False, True, True], 
               useUpsampling=True, outSizeChange=True)

# %%
from scipy.signal import decimate, resample
from scipy import interpolate
import numpy as np
import os

modelDict = torch.load('ResNet_Max.pth', map_location='cpu')
myNet.load_state_dict(modelDict['modelState'])

reSam, norDataLen = 3072, 512
xNew = np.linspace(201, 3500, num=3300, endpoint=True, dtype=np.int)

basePATH = 'C:\\Users\\CHENTIEJUN\\Desktop\\dataset'

# %%
basePATH = 'C:\\Users\\CHENTIEJUN\\Desktop\\dataset'
dataInfoPATH = os.path.join(basePATH, 'dataInfo20.txt')
dataLibraryPATH = os.path.join(basePATH, 'dataLibrary20.txt')
dataPath = os.path.join(basePATH, 'exData')

dataInfo = np.loadtxt(dataInfoPATH, dtype=str, delimiter='\n')
dataLibrary = np.loadtxt(dataLibraryPATH)

myNet.eval()
with torch.no_grad():
    for fileName in os.listdir(dataPath):
        filePATH = os.path.join(dataPath, fileName)
        outScore = np.zeros(len(dataLibrary))
        
        rawData = np.loadtxt(filePATH, comments='', unpack=True)

        cubicFunc = interpolate.interp1d(rawData[0], rawData[1], kind='next', fill_value='extrapolate')
        dataC = cubicFunc(xNew) #interpolation

        dataR = resample(dataC, reSam)
        dataX = np.trim_zeros(dataR, trim='b')
        dataLenX = len(dataX)
        num = dataLenX // norDataLen
        dataLenX //= num

        z = decimate(dataX, num, ftype='iir')
        dataMin, dataMax = z.min(), z.max()
        z = (z-dataMin) / (dataMax-dataMin)

        for i, material in enumerate(dataInfo):
            inPut1 = z
            inPut2 = dataLibrary[i]

            d1 = torch.unsqueeze(torch.tensor(inPut1, dtype=torch.float32), dim=0).to(device)
            d2 = torch.unsqueeze(torch.tensor(inPut2, dtype=torch.float32), dim=0).to(device)
            outPut = myNet(d1, d2)
            outScore[i] = torch.sigmoid(outPut)

        scoreMaxSort = np.flip(np.argsort(outScore))

# Library: AN_01.txt, test data: AN_26.txt, score: 1.0
# Library: AN_01.txt, test data: AN_27.txt, score: 1.0
# Library: AN_01.txt, test data: AN_28.txt, score: 1.0
# Library: AN_01.txt, test data: AN_29.txt, score: 1.0
# Library: AN_01.txt, test data: AN_30.txt, score: 1.0
# Library: AN_01.txt, test data: AN_31.txt, score: 1.0
# Library: AN_01.txt, test data: AN_32.txt, score: 1.0
# Library: AN_01.txt, test data: AN_33.txt, score: 1.0
# Library: AN_01.txt, test data: AN_34.txt, score: 1.0
# Library: AN_01.txt, test data: AN_35.txt, score: 1.0
# Library: AN_01.txt, test data: AN_36.txt, score: 1.0
# Library: AN_01.txt, test data: AN_37.txt, score: 1.0
# Library: AN_01.txt, test data: AN_38.txt, score: 1.0
# Library: AN_01.txt, test data: AN_40.txt, score: 1.0
# Library: AN_01.txt, test data: AN_41.txt, score: 1.0
# Library: AN_01.txt, test data: AN_42.txt, score: 1.0
# Library: AN_01.txt, test data: AN_43.txt, score: 1.0
# Library: AN_01.txt, test data: AN_44.txt, score: 1.0
# Library: AN_01.txt, test data: AN_45.txt, score: 1.0
# Library: AN_01.txt, test data: AN_46.txt, score: 1.0
# Library: AN_01.txt, test data: AN_47.txt, score: 1.0
# Library: AN_01.txt, test data: AN_48.txt, score: 1.0
# Library: AN_01.txt, test data: AN_49.txt, score: 1.0
# Library: AN_01.txt, test data: AN_50.txt, score: 1.0
# Library: AN_01.txt, test data: AN_51.txt, score: 1.0
# Library: AP_01.txt, test data: AP_01.txt, score: 1.0
# Library: AP_01.txt, test data: AP_02.txt, score: 1.0
# Library: AP_01.txt, test data: AP_03.txt, score: 1.0
# Library: AP_01.txt, test data: AP_04.txt, score: 0.9999998807907104
# Library: AP_01.txt, test data: AP_05.txt, score: 0.9999998807907104
# Library: AP_01.txt, test data: AP_06.txt, score: 0.9999997615814209
# Library: AP_01.txt, test data: AP_07.txt, score: 1.0
# Library: AP_01.txt, test data: AP_08.txt, score: 1.0
# Library: AP_01.txt, test data: AP_09.txt, score: 1.0
# Library: AP_01.txt, test data: AP_10.txt, score: 1.0
# Library: AP_01.txt, test data: AP_11.txt, score: 1.0
# Library: AP_01.txt, test data: AP_12.txt, score: 1.0
# Library: AP_01.txt, test data: AP_13.txt, score: 1.0
# Library: AP_01.txt, test data: AP_14.txt, score: 1.0
# Library: AP_01.txt, test data: AP_15.txt, score: 1.0
# Library: AP_01.txt, test data: AP_16.txt, score: 1.0
# Library: AP_01.txt, test data: AP_17.txt, score: 1.0
# Library: AP_01.txt, test data: AP_18.txt, score: 1.0
# Library: AP_01.txt, test data: AP_19.txt, score: 1.0
# Library: AP_01.txt, test data: AP_20.txt, score: 1.0
# Library: AP_01.txt, test data: AP_21.txt, score: 1.0
# Library: AP_01.txt, test data: AP_22.txt, score: 1.0
# Library: AP_01.txt, test data: AP_23.txt, score: 1.0
# Library: AP_01.txt, test data: AP_24.txt, score: 1.0
# Library: AP_01.txt, test data: AP_25.txt, score: 1.0
# Library: AP_01.txt, test data: AP_26.txt, score: 1.0
# Library: AP_01.txt, test data: AP_27.txt, score: 1.0
# Library: AP_01.txt, test data: AP_28.txt, score: 1.0
# Library: AP_01.txt, test data: AP_29.txt, score: 1.0
# Library: AP_01.txt, test data: AP_30.txt, score: 1.0
# Library: AP_01.txt, test data: AP_31.txt, score: 1.0
# Library: AP_01.txt, test data: AP_32.txt, score: 1.0
# Library: AP_01.txt, test data: AP_33.txt, score: 1.0
# Library: AP_01.txt, test data: AP_34.txt, score: 1.0
# Library: AP_01.txt, test data: AP_35.txt, score: 1.0
# Library: AP_01.txt, test data: AP_36.txt, score: 1.0
# Library: AP_01.txt, test data: AP_37.txt, score: 1.0
# Library: AP_01.txt, test data: AP_38.txt, score: 1.0
# Library: AP_01.txt, test data: AP_39.txt, score: 1.0
# Library: AP_01.txt, test data: AP_40.txt, score: 1.0
# Library: AP_01.txt, test data: AP_41.txt, score: 1.0
# Library: AP_01.txt, test data: AP_42.txt, score: 1.0
# Library: AP_01.txt, test data: AP_43.txt, score: 1.0
# Library: AP_01.txt, test data: AP_44.txt, score: 1.0
# Library: AP_01.txt, test data: AP_45.txt, score: 1.0
# Library: AP_01.txt, test data: AP_47.txt, score: 1.0
# Library: AP_01.txt, test data: AP_48.txt, score: 1.0
# Library: AP_01.txt, test data: AP_49.txt, score: 1.0
# Library: AP_01.txt, test data: AP_50.txt, score: 1.0
# Library: AP_01.txt, test data: AP_51.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_01.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_02.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_03.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_04.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_05.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_06.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_07.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_08.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_09.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_10.txt, score: 0.9999988079071045
# Library: DMDNB_01.txt, test data: DMDNB_11.txt, score: 0.9999983310699463
# Library: DMDNB_01.txt, test data: DMDNB_12.txt, score: 0.9999982118606567
# Library: DMDNB_01.txt, test data: DMDNB_14.txt, score: 0.9999980926513672
# Library: DMDNB_01.txt, test data: DMDNB_15.txt, score: 0.9999980926513672
# Library: DMDNB_01.txt, test data: DMDNB_16.txt, score: 0.9999978542327881
# Library: DMDNB_01.txt, test data: DMDNB_17.txt, score: 0.9999973773956299
# Library: DMDNB_01.txt, test data: DMDNB_18.txt, score: 0.9999977350234985
# Library: DMDNB_01.txt, test data: DMDNB_19.txt, score: 0.9999978542327881
# Library: DMDNB_01.txt, test data: DMDNB_20.txt, score: 0.9999973773956299
# Library: DMDNB_01.txt, test data: DMDNB_21.txt, score: 0.9999977350234985
# Library: DMDNB_01.txt, test data: DMDNB_24.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_25.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_26.txt, score: 0.9999998807907104
# Library: DMDNB_01.txt, test data: DMDNB_27.txt, score: 0.9999997615814209
# Library: DMDNB_01.txt, test data: DMDNB_28.txt, score: 0.9999997615814209
# Library: DMDNB_01.txt, test data: DMDNB_29.txt, score: 0.9999996423721313
# Library: DMDNB_01.txt, test data: DMDNB_30.txt, score: 0.9999996423721313
# Library: DMDNB_01.txt, test data: DMDNB_31.txt, score: 0.9999995231628418
# Library: DMDNB_01.txt, test data: DMDNB_32.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_33.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_34.txt, score: 0.9999998807907104
# Library: DMDNB_01.txt, test data: DMDNB_35.txt, score: 0.9999997615814209
# Library: DMDNB_01.txt, test data: DMDNB_36.txt, score: 0.9999996423721313
# Library: DMDNB_01.txt, test data: DMDNB_37.txt, score: 0.9999996423721313
# Library: DMDNB_01.txt, test data: DMDNB_38.txt, score: 0.9999996423721313
# Library: DMDNB_01.txt, test data: DMDNB_39.txt, score: 0.9999996423721313
# Library: DMDNB_01.txt, test data: DMDNB_40.txt, score: 0.9999995231628418
# Library: DMDNB_01.txt, test data: DMDNB_41.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_42.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_43.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_44.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_45.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_46.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_47.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_48.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_49.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_50.txt, score: 1.0
# Library: DMDNB_01.txt, test data: DMDNB_51.txt, score: 0.9999997615814209
# Library: DMDNB_01.txt, test data: DMDNB_52.txt, score: 0.9999995231628418
# Library: DMDNB_01.txt, test data: DMDNB_53.txt, score: 0.9999991655349731
# Library: HMTD_01.txt, test data: HMTD_01.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_02.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_03.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_04.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_05.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_06.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_07.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_08.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_09.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_10.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_11.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_12.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_13.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_14.txt, score: 1.0
# Library: HMTD_01.txt, test data: HMTD_15.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_06.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_07.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_08.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_09.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_10.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_11.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_12.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_13.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_14.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_15.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_16.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_17.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_18.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_19.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_20.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_21.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_22.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_23.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_24.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_25.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_26.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_27.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_28.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_29.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_30.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_31.txt, score: 0.9999992847442627
# Library: HNIW_01.txt, test data: HNIW_32.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_33.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_34.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_35.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_36.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_37.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_38.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_39.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_40.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_41.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_42.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_43.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_44.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_45.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_46.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_47.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_48.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_49.txt, score: 1.0
# Library: HNIW_01.txt, test data: HNIW_50.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_01.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_02.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_03.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_04.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_05.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_06.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_07.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_08.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_09.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_10.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ_11.txt, score: 1.0
# Library: NQ_01.txt, test data: NQ
# Library: Tetryl_01.txt, test data: Tetryl_21.txt, score: 0.9999995231628418
# Library: Tetryl_01.txt, test data: Tetryl_22.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_23.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_24.txt, score: 0.9999997615814209
# Library: Tetryl_01.txt, test data: Tetryl_25.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_26.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_27.txt, score: 0.9999988079071045
# Library: Tetryl_01.txt, test data: Tetryl_28.txt, score: 0.9999998807907104
# Library: Tetryl_01.txt, test data: Tetryl_29.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_30.txt, score: 0.999998927116394
# Library: Tetryl_01.txt, test data: Tetryl_31.txt, score: 0.9999996423721313
# Library: Tetryl_01.txt, test data: Tetryl_32.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_33.txt, score: 0.9999997615814209
# Library: Tetryl_01.txt, test data: Tetryl_34.txt, score: 0.9999998807907104
# Library: Tetryl_01.txt, test data: Tetryl_35.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_36.txt, score: 0.9999997615814209
# Library: Tetryl_01.txt, test data: Tetryl_37.txt, score: 0.9999998807907104
# Library: Tetryl_01.txt, test data: Tetryl_38.txt, score: 0.9999996423721313
# Library: Tetryl_01.txt, test data: Tetryl_39.txt, score: 0.9999998807907104
# Library: Tetryl_01.txt, test data: Tetryl_40.txt, score: 0.9999998807907104
# Library: Tetryl_01.txt, test data: Tetryl_41.txt, score: 0.9999998807907104
# Library: Tetryl_01.txt, test data: Tetryl_42.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_43.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_44.txt, score: 0.9999969005584717
# Library: Tetryl_01.txt, test data: Tetryl_45.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_46.txt, score: 0.9999969005584717
# Library: Tetryl_01.txt, test data: Tetryl_47.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_48.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_49.txt, score: 1.0
# Library: Tetryl_01.txt, test data: Tetryl_50.txt, score: 0.9999942779541016
# Library: TMETN_01.txt, test data: TMETN_01.txt, score: 0.9971818923950195
# Library: TMETN_01.txt, test data: TMETN_02.txt, score: 0.09839332848787308
# Library: TMETN_01.txt, test data: TMETN_03.txt, score: 0.00019729505584109575
# Library: TMETN_01.txt, test data: TMETN_04.txt, score: 0.06796491146087646
# Library: TMETN_01.txt, test data: TMETN_05.txt, score: 0.4027094841003418
# Library: TMETN_01.txt, test data: TMETN_06.txt, score: 0.007224533706903458
# Library: TMETN_01.txt, test data: TMETN_07.txt, score: 0.08787979930639267
# Library: TMETN_01.txt, test data: TMETN_08.txt, score: 0.015221929177641869
# Library: TMETN_01.txt, test data: TMETN_09.txt, score: 0.10808619856834412
# Library: TMETN_01.txt, test data: TMETN_10.txt, score: 0.02414262481033802
# Library: TMETN_01.txt, test data: TMETN_11.txt, score: 0.8320115804672241
# Library: TMETN_01.txt, test data: TMETN_12.txt, score: 0.9721627831459045
# Library: TMETN_01.txt, test data: TMETN_13.txt, score: 0.006635958794504404
# Library: TMETN_01.txt, test data: TMETN_14.txt, score: 0.19669468700885773
# Library: TMETN_01.txt, test data: TMETN_15.txt, score: 0.447164922952652
# Library: TMETN_01.txt, test data: TMETN_16.txt, score: 0.6789304614067078
# Library: TMETN_01.txt, test data: TMETN_17.txt, score: 0.36437544226646423
# Library: TMETN_01.txt, test data: TMETN_18.txt, score: 0.2096654623746872
# Library: TMETN_01.txt, test data: TMETN_19.txt, score: 0.23587994277477264
# Library: TMETN_01.txt, test data: TMETN_20.txt, score: 0.13873158395290375
# Library: TMETN_01.txt, test data: TMETN_21.txt, score: 0.9267607927322388
# Library: TMETN_01.txt, test data: TMETN_22.txt, score: 0.8481495380401611
# Library: TMETN_01.txt, test data: TMETN_23.txt, score: 0.08122193813323975
# Library: TMETN_01.txt, test data: TMETN_24.txt, score: 0.39667242765426636
# Library: TMETN_01.txt, test data: TMETN_25.txt, score: 0.9770650863647461
# Library: TMETN_01.txt, test data: TMETN_26.txt, score: 0.1822628676891327
# Library: TMETN_01.txt, test data: TMETN_27.txt, score: 0.9403501749038696
# Library: TMETN_01.txt, test data: TMETN_28.txt, score: 0.7636393904685974
# Library: TMETN_01.txt, test data: TMETN_29.txt, score: 0.17637918889522552
# Library: TMETN_01.txt, test data: TMETN_30.txt, score: 0.18279798328876495
# Library: TMETN_01.txt, test data: TMETN_31.txt, score: 0.39637187123298645
# Library: TMETN_01.txt, test data: TMETN_32.txt, score: 0.10062859207391739
# Library: TMETN_01.txt, test data: TMETN_33.txt, score: 0.6059393286705017
# Library: TMETN_01.txt, test data: TMETN_34.txt, score: 0.948093056678772
# Library: TMETN_01.txt, test data: TMETN_35.txt, score: 0.3442789316177368
# Library: TMETN_01.txt, test data: TMETN_36.txt, score: 0.543107807636261
# Library: TMETN_01.txt, test data: TMETN_37.txt, score: 0.48913857340812683
# Library: TMETN_01.txt, test data: TMETN_38.txt, score: 0.15605755150318146
# Library: TMETN_01.txt, test data: TMETN_39.txt, score: 0.6056099534034729
# Library: TMETN_01.txt, test data: TMETN_40.txt, score: 0.766260027885437
# Library: TMETN_01.txt, test data: TMETN_41.txt, score: 0.554965078830719
# Library: TMETN_01.txt, test data: TMETN_42.txt, score: 0.6251569390296936
# Library: TMETN_01.txt, test data: TMETN_43.txt, score: 0.9346626996994019
# Library: TMETN_01.txt, test data: TMETN_44.txt, score: 0.25772297382354736
# Library: TMETN_01.txt, test data: TMETN_45.txt, score: 0.9595293998718262
# Library: TMETN_01.txt, test data: TMETN_46.txt, score: 0.9565207958221436
# Library: TMETN_01.txt, test data: TMETN_47.txt, score: 0.27618521451950073
# Library: TMETN_01.txt, test data: TMETN_48.txt, score: 0.9633244276046753
# Library: TMETN_01.txt, test data: TMETN_49.txt, score: 0.4507202208042145
# Library: TMETN_01.txt, test data: TMETN_50.txt, score: 0.41415169835090637
# Library: TNT_01.txt, test data: TNT_01.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_02.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_03.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_04.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_05.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_06.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_07.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_08.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_09.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_11.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_12.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_13.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_14.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_15.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_16.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_17.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_18.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_19.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_20.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_21.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_22.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_23.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_24.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_25.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_26.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_27.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_28.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_29.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_30.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_31.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_32.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_33.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_34.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_35.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_36.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_37.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_38.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_39.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_40.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_41.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_42.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_43.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_45.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_46.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_47.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_48.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_49.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_50.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_51.txt, score: 1.0
# Library: TNT_01.txt, test data: TNT_52.txt, score: 1.0
